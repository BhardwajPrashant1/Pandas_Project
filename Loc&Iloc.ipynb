# %%
import pandas as pd

# %%
df=pd.read_csv("D:\PortfolioProject_DataSets\CovidAnalyzea.Visualize\PandasCleaning\Salesanalysis.csv")

# %%
df.head(4)
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   176558        USB-C Charging Cable                2      11.95
# 1      NaN                         NaN              NaN        NaN
# 2   176559  Bose SoundSport Headphones                1      99.99
# 3   176560                Google Phone                1        600
#
#        Order Date                      Purchase Address
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001
# 1             NaN                                   NaN
# 2  04/07/19 22:30     682 Chestnut St, Boston, MA 02215
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001

# %%
df['Order ID']
# Out:
# 0         176558
# 1            NaN
# 2         176559
# 3         176560
# 4         176560
#            ...
# 186845    259353
# 186846    259354
# 186847    259355
# 186848    259356
# 186849    259357
# Name: Order ID, Length: 186850, dtype: object

# %%
df
# Out:
#        Order ID                     Product Quantity Ordered Price Each  \
# 0        176558        USB-C Charging Cable                2      11.95
# 1           NaN                         NaN              NaN        NaN
# 2        176559  Bose SoundSport Headphones                1      99.99
# 3        176560                Google Phone                1        600
# 4        176560            Wired Headphones                1      11.99
# ...         ...                         ...              ...        ...
# 186845   259353      AAA Batteries (4-pack)                3       2.99
# 186846   259354                      iPhone                1        700
# 186847   259355                      iPhone                1        700
# 186848   259356      34in Ultrawide Monitor                1     379.99
# 186849   259357        USB-C Charging Cable                1      11.95
#
#             Order Date                         Purchase Address
# ...

# %%
df.loc[20]
# Out:
# Order ID                                          176575
# Product                           AAA Batteries (4-pack)
# Quantity Ordered                                       1
# Price Each                                          2.99
# Order Date                                04/27/19 00:30
# Purchase Address    433 Hill St, New York City, NY 10001
# Name: 20, dtype: object

# %%
df.iloc[20]
# Out:
# Order ID                                          176575
# Product                           AAA Batteries (4-pack)
# Quantity Ordered                                       1
# Price Each                                          2.99
# Order Date                                04/27/19 00:30
# Purchase Address    433 Hill St, New York City, NY 10001
# Name: 20, dtype: object

# %%
#lets make order ID as index instead of default one
df.set_index('Order ID',inplace=True)

# %%
df
# Out:
#                              Product Quantity Ordered Price Each  \
# Order ID
# 176558          USB-C Charging Cable                2      11.95
# NaN                              NaN              NaN        NaN
# 176559    Bose SoundSport Headphones                1      99.99
# 176560                  Google Phone                1        600
# 176560              Wired Headphones                1      11.99
# ...                              ...              ...        ...
# 259353        AAA Batteries (4-pack)                3       2.99
# 259354                        iPhone                1        700
# 259355                        iPhone                1        700
# 259356        34in Ultrawide Monitor                1     379.99
# 259357          USB-C Charging Cable                1      11.95
#
#               Order Date                         Purchase Address
# Order ID
# 176558    04/19/19 08:46             917 1st St, Dallas, TX 75001
# ...

# %%
#Select data with the help of Index Label
df.loc['176559']
# Out:
# Product                    Bose SoundSport Headphones
# Quantity Ordered                                    1
# Price Each                                      99.99
# Order Date                             04/07/19 22:30
# Purchase Address    682 Chestnut St, Boston, MA 02215
# Name: 176559, dtype: object

# %%
#Providing same input as in avove line but change loc function to iloc
df.iloc[176559]

#Outpur will be different as iloc select data with integer location
# Out:
# Product                            AA Batteries (4-pack)
# Quantity Ordered                                       1
# Price Each                                          3.84
# Order Date                                09/26/19 17:11
# Purchase Address    343 Church St, Los Angeles, CA 90001
# Name: 249490, dtype: object

# %%
#Slicing Data

# %%
#Select Product name and price for Product wity Order ID:176559
df.loc[['176559'],['Product','Price Each']]
# Out:
#                              Product Price Each
# Order ID
# 176559    Bose SoundSport Headphones      99.99

# %%
#Select Product name and price for ALL Order IDs
df.loc[:,['Product','Price Each']]
# Out:
#                              Product Price Each
# Order ID
# 176558          USB-C Charging Cable      11.95
# NaN                              NaN        NaN
# 176559    Bose SoundSport Headphones      99.99
# 176560                  Google Phone        600
# 176560              Wired Headphones      11.99
# ...                              ...        ...
# 259353        AAA Batteries (4-pack)       2.99
# 259354                        iPhone        700
# 259355                        iPhone        700
# 259356        34in Ultrawide Monitor     379.99
# 259357          USB-C Charging Cable      11.95
#
# [186850 rows x 2 columns]

# %%
#Select all columns where Id is this:
df.loc[['176558','176559'],:]
# Out:
#                              Product Quantity Ordered Price Each  \
# Order ID
# 176558          USB-C Charging Cable                2      11.95
# 176559    Bose SoundSport Headphones                1      99.99
#
#               Order Date                   Purchase Address
# Order ID
# 176558    04/19/19 08:46       917 1st St, Dallas, TX 75001
# 176559    04/07/19 22:30  682 Chestnut St, Boston, MA 02215

# %%
#df.loc[0:2,0:1] --this will throw an error as we are giving interger location in loc function which is incorrect

# %%
df.iloc[0:2,0:1] #this will give correct output
# Out:
#                        Product
# Order ID
# 176558    USB-C Charging Cable
# NaN                        NaN

# %%
df.head()
# Out:
#                              Product Quantity Ordered Price Each  \
# Order ID
# 176558          USB-C Charging Cable                2      11.95
# NaN                              NaN              NaN        NaN
# 176559    Bose SoundSport Headphones                1      99.99
# 176560                  Google Phone                1        600
# 176560              Wired Headphones                1      11.99
#
#               Order Date                      Purchase Address
# Order ID
# 176558    04/19/19 08:46          917 1st St, Dallas, TX 75001
# NaN                  NaN                                   NaN
# 176559    04/07/19 22:30     682 Chestnut St, Boston, MA 02215
# 176560    04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001
# 176560    04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001

# %%
#Lets first remove all the Nan
df.dropna(inplace=True)

# %%
df
# Out:
#                              Product Quantity Ordered Price Each  \
# Order ID
# 176558          USB-C Charging Cable                2      11.95
# 176559    Bose SoundSport Headphones                1      99.99
# 176560                  Google Phone                1        600
# 176560              Wired Headphones                1      11.99
# 176561              Wired Headphones                1      11.99
# ...                              ...              ...        ...
# 259353        AAA Batteries (4-pack)                3       2.99
# 259354                        iPhone                1        700
# 259355                        iPhone                1        700
# 259356        34in Ultrawide Monitor                1     379.99
# 259357          USB-C Charging Cable                1      11.95
#
#               Order Date                         Purchase Address
# Order ID
# 176558    04/19/19 08:46             917 1st St, Dallas, TX 75001
# ...

# %%
#df.loc[pd.to_numeric(df['Price Each'])>50,'Product'] ValueError: Unable to parse string "Price Each" at position 517

# %%
df.iloc[517]
# Out:
# Product                      Product
# Quantity Ordered    Quantity Ordered
# Price Each                Price Each
# Order Date                Order Date
# Purchase Address    Purchase Address
# Name: Order ID, dtype: object

# %%
df.drop(df.index[517],inplace=True)

# %%
#Give product name where price >50 
df.loc[pd.to_numeric(df['Price Each'])>50,'Product']
# Out:
# Order ID
# 176559    Bose SoundSport Headphones
# 176560                  Google Phone
# 176563    Bose SoundSport Headphones
# 176565            Macbook Pro Laptop
# 176567                  Google Phone
#                      ...
# 259350                  Google Phone
# 259351      Apple Airpods Headphones
# 259354                        iPhone
# 259355                        iPhone
# 259356        34in Ultrawide Monitor
# Name: Product, Length: 82289, dtype: object
